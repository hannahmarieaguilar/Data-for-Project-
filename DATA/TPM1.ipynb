# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

import pandas as pd
import warnings
warnings.simplefilter("ignore")

# %%
TPM1_Path = pd.read_csv("TPM1.txt", sep='\t')
newTPM1_Path = TPM1_Path['Condition(s)'].str.contains("Hypertrophic cardiomyopathy")
TPM1_Path1 = TPM1_Path[newTPM1_Path].dropna(subset=['Protein change'])
TPM1_Path1
# Out:
#                                           Name Gene(s)       Protein change  \
# 0   NM_001018005.2(TPM1):c.284T>C (p.Val95Ala)    TPM1    V95A, V137A, V59A
# 1  NM_001018005.2(TPM1):c.523G>A (p.Asp175Asn)    TPM1  D175N, D139N, D217N
# 2  NM_001018005.2(TPM1):c.539A>G (p.Glu180Gly)    TPM1  E180G, E222G, E144G
# 3  NM_001018005.2(TPM1):c.574G>A (p.Glu192Lys)    TPM1  E192K, E156K, E234K
# 4  NM_001018005.2(TPM1):c.644C>T (p.Ser215Leu)    TPM1  S215L, S179L, S257L
# 5  NM_001018005.2(TPM1):c.688G>A (p.Asp230Asn)    TPM1  D230N, D194N, D272N
#
#                                         Condition(s)  \
# 0  Cardiovascular phenotype|not provided|Hypertro...
# 1  Cardiovascular phenotype|not provided|Cardiomy...
# 2           not provided|Hypertrophic cardiomyopathy
# 3  Cardiovascular phenotype|not provided|Cardiomy...
# 4  Cardiovascular phenotype|not provided|Cardiomy...
# 5  not provided|Dilated cardiomyopathy 1Y|Hypertr...
#
#                Clinical significance (Last reviewed)  \
# ...

# %%
TPM1_LP = pd.read_csv("TPM1_LP.txt", sep='\t')
newTPM1_LP = TPM1_LP['Condition(s)'].str.contains("Hypertrophic cardiomyopathy")
TPM1_LP1 = TPM1_LP[newTPM1_LP].dropna(subset=['Protein change'])
TPM1_LP1
# Out:
#                                            Name Gene(s)       Protein change  \
# 6    NM_001018005.2(TPM1):c.179A>G (p.Tyr60Cys)    TPM1          Y60C, Y102C
# 7    NM_001018005.2(TPM1):c.184G>C (p.Glu62Gln)    TPM1          E62Q, E104Q
# 8    NM_001018005.2(TPM1):c.250G>A (p.Asp84Asn)    TPM1    D84N, D126N, D48N
# 10   NM_001018005.2(TPM1):c.284T>C (p.Val95Ala)    TPM1    V95A, V137A, V59A
# 12   NM_001018005.2(TPM1):c.292G>A (p.Glu98Lys)    TPM1    E62K, E98K, E140K
# 21  NM_001018005.2(TPM1):c.538G>A (p.Glu180Lys)    TPM1  E144K, E180K, E222K
# 22  NM_001018005.2(TPM1):c.539A>T (p.Glu180Val)    TPM1  E180V, E144V, E222V
# 23  NM_001018005.2(TPM1):c.559G>C (p.Glu187Gln)    TPM1  E187Q, E229Q, E151Q
# 24  NM_001018005.2(TPM1):c.574G>A (p.Glu192Lys)    TPM1  E192K, E156K, E234K
# 26  NM_001018005.2(TPM1):c.616T>G (p.Ser206Ala)    TPM1  S170A, S206A, S248A
# 29  NM_001018005.2(TPM1):c.644C>T (p.Ser215Leu)    TPM1  S215L, S179L, S257L
# ...

# %%
combined10 = [TPM1_LP, TPM1_Path1]
TPM1_combined = pd.concat(combined10)
TPM1_combined
# Out:
#                                                  Name  \
# 0            NM_001018005.2(TPM1):c.23T>G (p.Met8Arg)
# 1        NM_001018005.2(TPM1):c.85AAG[1] (p.Lys30del)
# 2                     NM_001018005.2(TPM1):c.114+2T>C
# 3          NM_001018005.2(TPM1):c.128T>C (p.Leu43Pro)
# 4          NM_001018005.2(TPM1):c.163G>T (p.Asp55Tyr)
# 5          NM_001018005.2(TPM1):c.163G>A (p.Asp55Asn)
# 6          NM_001018005.2(TPM1):c.179A>G (p.Tyr60Cys)
# 7          NM_001018005.2(TPM1):c.184G>C (p.Glu62Gln)
# 8          NM_001018005.2(TPM1):c.250G>A (p.Asp84Asn)
# 9          NM_001018005.2(TPM1):c.251A>C (p.Asp84Ala)
# 10         NM_001018005.2(TPM1):c.284T>C (p.Val95Ala)
# 11         NM_001018005.2(TPM1):c.289G>C (p.Glu97Gln)
# 12         NM_001018005.2(TPM1):c.292G>A (p.Glu98Lys)
# 13        NM_001018005.2(TPM1):c.341A>G (p.Glu114Gly)
# 14        NM_001018005.2(TPM1):c.388A>G (p.Ile130Val)
# 15        NM_001018005.2(TPM1):c.412G>A (p.Glu138Lys)
# ...

# %%
TPM1 = TPM1_combined[['Name']]
np.array(np.array(TPM1['Name'].str.split(' ')).item(0)).item(0)
lst = []
for i in np.arange(42):
    lst = np.append(lst, np.array(np.array(TPM1['Name'].str.split(' ')).item(i)).item(0))
    
lst
TPM1 = Table().with_columns('Name', lst)
TPM1.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Name</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>NM_001018005.2(TPM1):c.23T>G     </td>
#         </tr>
#         <tr>
#             <td>NM_001018005.2(TPM1):c.85AAG[1]  </td>
#         </tr>
#         <tr>
#             <td>NM_001018005.2(TPM1):c.114+2T>C  </td>
#         </tr>
#         <tr>
#             <td>NM_001018005.2(TPM1):c.128T>C    </td>
#         </tr>
#         <tr>
#             <td>NM_001018005.2(TPM1):c.163G>T    </td>
#         </tr>
#         <tr>
#             <td>NM_001018005.2(TPM1):c.163G>A    </td>
#         </tr>
#         <tr>
#             <td>NM_001018005.2(TPM1):c.179A>G    </td>
#         </tr>
#         <tr>
#             <td>NM_001018005.2(TPM1):c.184G>C    </td>
#         </tr>
#         <tr>
#             <td>NM_001018005.2(TPM1):c.250G>A    </td>
#         </tr>
#         <tr>
# ...

# %%
TPM1_ensembl = pd.read_csv('TPM1_ensembl.txt', sep='\t')
pd.set_option('display.max_columns', None)
TPM1_ensembl
emsembl_TPM1 = TPM1_ensembl['SYMBOL'].str.contains("TPM1")
TPM1_ensembl[emsembl_TPM1]

new = TPM1_ensembl['Consequence'].str.contains('missense_variant|stop_gained|frame_shift')
test = TPM1_ensembl[new]
test1 = test[['#Uploaded_variation', 'Consequence']]
test1
# Out:
#                 #Uploaded_variation                              Consequence
# 0      NM_001018005.2(TPM1):c.23T>G                         missense_variant
# 1      NM_001018005.2(TPM1):c.23T>G                         missense_variant
# 2      NM_001018005.2(TPM1):c.23T>G                         missense_variant
# 3      NM_001018005.2(TPM1):c.23T>G                         missense_variant
# 4      NM_001018005.2(TPM1):c.23T>G                         missense_variant
# ...                             ...                                      ...
# 1443  NM_001018005.2(TPM1):c.749A>T                         missense_variant
# 1444  NM_001018005.2(TPM1):c.749A>T  missense_variant,NMD_transcript_variant
# 1445  NM_001018005.2(TPM1):c.749A>T  missense_variant,NMD_transcript_variant
# 1446  NM_001018005.2(TPM1):c.749A>T                         missense_variant
# 1447  NM_001018005.2(TPM1):c.749A>T  missense_variant,NMD_transcript_variant
#
# [677 rows x 2 columns]

# %%
me = test1.groupby(['Consequence']).agg('count')
me
# Out:
#                                          #Uploaded_variation
# Consequence
# missense_variant                                         562
# missense_variant,NMD_transcript_variant                  114
# stop_gained,NMD_transcript_variant                         1

# %%
plot = me.plot.pie(y='#Uploaded_variation', figsize=(5, 5))

# %%
TPM1_VUS = pd.read_csv("TPM1_VUS.txt", sep='\t')
newTPM1_VUS = TPM1_VUS['Condition(s)'].str.contains("Hypertrophic cardiomyopathy", case=False, na=False)
TPM1_VUS1 =TPM1_VUS[newTPM1_VUS].dropna(subset=['Protein change'])
TPM1_VUS1
# Out:
#                                             Name Gene(s)  \
# 8        NM_001018005.2(TPM1):c.1A>G (p.Met1Val)    TPM1
# 9        NM_001018005.2(TPM1):c.2T>C (p.Met1Thr)    TPM1
# 11       NM_001018005.2(TPM1):c.4G>C (p.Asp2His)    TPM1
# 14       NM_001018005.2(TPM1):c.8C>T (p.Ala3Val)    TPM1
# 17   NM_001018005.2(TPM1):c.14AGA[2] (p.Lys7del)    TPM1
# ..                                           ...     ...
# 301  NM_001018005.2(TPM1):c.841A>G (p.Met281Val)    TPM1
# 304  NM_001018005.2(TPM1):c.851T>C (p.Ile284Thr)    TPM1
# 309  NM_001018005.2(TPM1):c.852A>G (p.Ile284Met)    TPM1
# 310    NM_001018005.2(TPM1):c.852A>C (p.Ile284=)    TPM1
# 313                NM_001018005.2(TPM1):c.*11T>G    TPM1
#
#                         Protein change  \
# 8                                  M1V
# 9                                  M1T
# 11                                 D2H
# 14                                 A3V
# 17                               K7del
# ...
